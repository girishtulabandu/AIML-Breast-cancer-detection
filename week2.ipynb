# %%
import pandas as pd
df = pd.read_csv('/Users/girish.tulabandu/personal/AIML-Breast-cancer-detection/cancer dataset.csv')

# %% [markdown]
# ### 1. Open the file in your python notebook, print first 5 rows of the dataset and mention what are the dependent and independent variables in the Data.

# %%
df2 = df.head(5)
df2
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %% [markdown]
# ### 2. Find the statistical parameters of the Data that you have
#
# radius_mean, texture_mean, perimeter_mean, area_mean, smothness_mean, compactness_mean, concavity_mean, concavepoints_mean

# %% [markdown]
# ### 3.Find the shape of the Dataset in hand.

# %%
df.shape
# Out:
# (569, 32)

# %% [markdown]
# ### 4.Find missing values from the Dataset

# %%
df.columns[df.isnull().any()]
# Out:
# Index([], dtype='object')

# %% [markdown]
# ### 5.  Find the value count of B(Benign) and M(Malignant) cancer cells in the column "diagnosis"

# %%
df[df['diagnosis'] == "M"].shape[0]
# Out:
# 212

# %%
df[df['diagnosis'] == "B"].shape[0]
# Out:
# 357

# %%
df3 = df.iloc[0:,0:5]
df3
# Out:
#            id diagnosis  radius_mean  texture_mean  perimeter_mean
# 0      842302         M        17.99         10.38          122.80
# 1      842517         M        20.57         17.77          132.90
# 2    84300903         M        19.69         21.25          130.00
# 3    84348301         M        11.42         20.38           77.58
# 4    84358402         M        20.29         14.34          135.10
# ..        ...       ...          ...           ...             ...
# 564    926424         M        21.56         22.39          142.00
# 565    926682         M        20.13         28.25          131.20
# 566    926954         M        16.60         28.08          108.30
# 567    927241         M        20.60         29.33          140.10
# 568     92751         B         7.76         24.54           47.92
#
# [569 rows x 5 columns]

# %% [markdown]
# ### 6.Creating a pairplot and mention the findings

# %%
import seaborn as sns
sns.pairplot(df3, hue='diagnosis')

# %% [markdown]
# 1. perimeter_mean increasing with radius_mean
# 2.

# %% [markdown]
# ### 7. Create a correlation matrix and mention strongly, weakly and negatively correlated quantities.

# %%
df3.corr(method="pearson")
# Out:
#                       id  radius_mean  texture_mean  perimeter_mean
# id              1.000000     0.074626      0.099770        0.073159
# radius_mean     0.074626     1.000000      0.323782        0.997855
# texture_mean    0.099770     0.323782      1.000000        0.329533
# perimeter_mean  0.073159     0.997855      0.329533        1.000000

# %% [markdown]
# First four columns are strongly correlated to each other

# %% [markdown]
# ### 8. Create a heatmap of the correlated features (helps in visualization

# %%
sns.heatmap(df3.corr(), annot=True,fmt="0.0%")
